# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
aluguel = pd.read_csv("C:\\Users\\anara\\Documents\\Curso de ciencia de dados (T) UNIPE\\Fabrica\\aluguel_residencial.csv", sep=";")
aluguel
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %%
from matplotlib.pyplot import figure
figure(figsize = (15,6), dpi = 80)

# %%
x = aluguel["Area"]
y = aluguel["Valor"]
plt.scatter (x,y)

# %%
aluguel.sort_values (by = "Valor", ascending = False)
# Out:
#                      Tipo             Bairro  Quartos  Vagas  Suites  Area  \
# 18348  Casa de Condomínio    Barra da Tijuca        5      6       5  1200
# 18697  Casa de Condomínio    Barra da Tijuca        5      4       5   850
# 17919  Casa de Condomínio    Barra da Tijuca        5      6       4  1000
# 17902  Casa de Condomínio    Barra da Tijuca        4      4       4   800
# 18762  Casa de Condomínio    Barra da Tijuca        4      4       2   600
# ...                   ...                ...      ...    ...     ...   ...
# 19634           Quitinete               Anil        1      0       0    20
# 4306          Apartamento  Engenho de Dentro        1      0       0    30
# 19150           Quitinete        Jacarepaguá        1      0       0    20
# 11120         Apartamento             Leblon        0      0       0    15
# 19147           Quitinete         Copacabana        0      0       0    36
#
#          Valor  Condominio     IPTU  Valor m2 Tipo Agregado
# ...
